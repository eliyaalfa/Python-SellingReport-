# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
plt.style.use('seaborn')

# %%
soal = pd.read_csv('dataset penjualan hp.csv',index_col=0, parse_dates=True)

# %%
soal
# Out:
#                   Lokasi Pembelian                         Tipe    Merek  \
# Tanggal Transaksi
# 2018-04-24              BOJONEGORO        SAMSUNG GALAXY C7 PRO  SAMSUNG
# 2018-04-24                 JOMBANG       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24               MOJOKERTO       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24                SURABAYA       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24              BOJONEGORO       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24                 JOMBANG       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24                SURABAYA       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24               MOJOKERTO       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24                 JOMBANG       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24                 JOMBANG       XIAOMI REDMI 6 3/32 GB   XIAOMI
# 2018-04-24               MOJOKERTO                 OPPO F3 PLUS     OPPO
# 2018-04-24                SURABAYA                 OPPO F5 6 GB     OPPO
# ...

# %%
soal.describe()
# Out:
#               Usia    Harga Jual
# count  1000.000000  1.000000e+03
# mean     36.572000  1.838885e+06
# std      11.421877  2.656487e+05
# min      18.000000  1.649000e+06
# 25%      27.000000  1.649000e+06
# 50%      35.000000  1.649000e+06
# 75%      45.000000  2.049000e+06
# max      77.000000  4.488000e+06

# %%
soal.count()
# Out:
# Lokasi Pembelian    1000
# Tipe                1000
# Merek               1000
# Warna               1000
# Jenis Kelamin       1000
# Kota                1000
# Propinsi            1000
# Usia                1000
# Jenis Pembayaran    1000
# Pekerjaan           1000
# Pendidikan          1000
# Harga Jual          1000
# dtype: int64

# %%
lokasi.value_counts()
# Out:
# SURABAYA      323
# SIDOARJO      164
# GRESIK        130
# JOMBANG        86
# TUBAN          77
# BOJONEGORO     59
# MOJOKERTO      55
# PAMEKASAN      38
# SUMENEP        33
# BANGKALAN      29
# LAMONGAN        6
# Name: Lokasi Pembelian, dtype: int64

# %%
index_xiaomi = merk == 'XIAOMI'
index_samsung = merk == 'SAMSUNG'
index_vivo = merk == 'VIVO'
index_apple = merk == 'APPLE'
index_oppo = merk == 'OPPO'

xiaomi = soal[index_xiaomi]
samsung = soal[index_samsung]
vivo = soal[index_vivo]
apple = soal[index_apple]
oppo = soal[index_oppo]

# %%
df = soal['Lokasi Pembelian'].value_counts()
df
# Out:
# SURABAYA      323
# SIDOARJO      164
# GRESIK        130
# JOMBANG        86
# TUBAN          77
# BOJONEGORO     59
# MOJOKERTO      55
# PAMEKASAN      38
# SUMENEP        33
# BANGKALAN      29
# LAMONGAN        6
# Name: Lokasi Pembelian, dtype: int64

# %%
df.plot('bar')

# %%
df1 = soal['Tipe'].value_counts()
df1
# Out:
# SAMSUNG GALAXY A8 PLUS         238
# XIAOMI MI A2 LITE 3/32 GB      221
# XIAOMI MI 6 4/64 GB            114
# VIVO XSHOT                      84
# SAMSUNG GALAXY A8 STAR          57
# IPHONE SE 16 GB                 47
# VIVO XPLAY 3S                   40
# OPPO F5                         26
# XIAOMI REDMI 6 3/32 GB          21
# XIAOMI MI NOTE 3/16 GB          17
# IPHONE 5C 16 GB                 16
# OPPO F9 6 GB                    15
# SAMSUNG GALAXY C7 PRO           14
# XIAOMI POCOPHONE FI 6/64 GB     11
# OPPO F1                         10
# IPHONE 5C 32 GB                 10
# OPPO F1S                         8
# IPHONE 6S 16 GB                  8
# XIAOMI REDMI 5 PLUS 3/32 GB      7
# XIAOMI REDMI 6 4/64 GB           6
# OPPO F7 6 GB                     5
# OPPO F1 PLUS                     5
# XIAOMI MI A2 LITE 4/64 GB        5
# SAMSUNG GALAXY S9                4
# XIAOMI REDMI 5 2/16 GB           3
# OPPO F3                          2
# SAMSUNG GALAXY A8                2
# ...

# %%
df1.plot('bar')

# %%
df2 = soal['Pekerjaan'].value_counts()
df2
# Out:
# KARYAWAN SWASTA                    353
# PELAJAR/MAHASISWA                  176
# WIRASWASTA                         168
# LAIN-LAIN                          123
# IBU RUMAH TANGGA                   107
# PNS                                 48
# PROFESIONAL (GURU/DOSEN/DOKTER)     14
# TNI/POLRI                            9
# NELAYAN/PERIKANAN                    1
# BELUM/TIDAK BEKERJA                  1
# Name: Pekerjaan, dtype: int64

# %%
df2.plot('bar')

# %%
warna_yang_paling_banyak_beli = samsung.filter(['Warna'], axis=1)
warna_yang_paling_banyak_beli.describe()
# Out:
#         Warna
# count     316
# unique      6
# top     HITAM
# freq      121

# %% [markdown]
# 1. custumer paling banyak karyawan swasta
# 2. paling banyak hp terjual samsung galaxy a8 plus
# 3. lokasi pembelian terbanyak di surabaya
# 4. lokasi paing sedikit peminatnya lamongan
# 5. warna hp samsung galaxy a8 paling banyak diminati warna hitam
